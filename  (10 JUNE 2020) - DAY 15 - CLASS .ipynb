# %% [markdown]
# DOCUMENT : [CLICK_HERE](https://docs.google.com/document/d/1U9wQxCZ38Feh6srA_bv9siFCEjdgNLPGTuz2pgFrtAo/edit)

# %% [markdown]
# SESSION DOC : [CLICK-HERE](https://docs.google.com/document/d/1nG5Do1elQIdORPoI85uOV6b0i6lSqgU8R80rHe8Z2nQ/edit)

# %% [markdown]
# ### import the required packages

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Getting the data from seaborn

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# plots using
#
#    - pandas
#    - matplotlib
#    - seaborns

# %%
tips['total_bill'].hist()

# %%
plt.hist(tips['total_bill'])
# Out:
# (array([ 7., 42., 68., 51., 31., 19., 12.,  7.,  3.,  4.]),
#  array([ 3.07 ,  7.844, 12.618, 17.392, 22.166, 26.94 , 31.714, 36.488,
#         41.262, 46.036, 50.81 ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(tips['total_bill'],bins=5)
# Out:
# (array([ 49., 119.,  50.,  19.,   7.]),
#  array([ 3.07 , 12.618, 22.166, 31.714, 41.262, 50.81 ]),
#  <a list of 5 Patch objects>)

# %%
tips['total_bill'].describe()
# Out:
# count    244.000000
# mean      19.785943
# std        8.902412
# min        3.070000
# 25%       13.347500
# 50%       17.795000
# 75%       24.127500
# max       50.810000
# Name: total_bill, dtype: float64

# %%
np.linspace(3.07,50.810000,11)
# Out:
# array([ 3.07 ,  7.844, 12.618, 17.392, 22.166, 26.94 , 31.714, 36.488,
#        41.262, 46.036, 50.81 ])

# %%
((tips['total_bill']>=3.07)& (tips['total_bill']<= 7.844)).sum()
# Out:
# 7

# %%
sns.distplot(tips['total_bill'],kde=False)

# %% [markdown]
# ### Relational
#   - b/n two numerical columns
#   - relplot
#      - Scatterplot -relplot(kind=’scatter’)
#      - lineplot

# %%
sns.relplot("total_bill","tip",data=tips)

# %%
sns.relplot("total_bill","tip",data=tips,hue='smoker')

# %%
sns.relplot("total_bill","tip",data=tips,col='smoker')

# %%
sns.relplot("total_bill","tip",data=tips,hue='smoker',col='sex')

# %%
sns.relplot("total_bill","tip",data=tips,hue='smoker',style='smoker')

# %%
sns.relplot("total_bill","tip",data=tips,kind='scatter')

# %%
sns.relplot("total_bill","tip",data=tips,kind='line')

# %% [markdown]
# ### check the package version

# %%
sns.__version__# double undercore at the beging and end ---dunder
# Out:
# '0.10.0'

# %%
pd.__version__
# Out:
# '1.0.1'

# %%
sns.scatterplot("total_bill","tip",data=tips)

# %% [markdown]
# ### categorical plot
# - Categorical scatterplots:
#   - stripplot() (with kind="strip"; the default)
#   - swarmplot() (with kind="swarm")
# - Categorical distribution plots:
#   - boxplot() (with kind="box")
#   - violinplot() (with kind="violin")
#   - boxenplot() (with kind="boxen")
# - Categorical estimate plots:
#   - pointplot() (with kind="point")
#   - barplot() (with kind="bar")
#   - countplot() (with kind="count"

# %%
sns.catplot("day",'tip',data=tips) # default kind is strip

# %% [markdown]
# #### Swarmplot

# %%
sns.catplot("day",'tip',data=tips,kind='swarm')

# %%
sns.catplot("day",'tip',data=tips,kind='swarm',hue='smoker')

# %%
sns.catplot("day",'tip',data=tips,kind='swarm',hue='smoker',col='sex')

# %% [markdown]
# - Try for daywise total bill
# - try for timewise total bill
# - try for sex total bill

# %%
sns.catplot("time",'tip',data=tips,kind='swarm',hue='smoker')

# %% [markdown]
# #### boxplot

# %%
sns.catplot("day",'tip',data=tips,kind='box')

# %%
sns.catplot("day",'total_bill',data=tips,kind='box')

# %%
sns.catplot("day",'total_bill',data=tips,kind='box',hue='sex')

# %% [markdown]
# #### count

# %%
sns.catplot("day",data=tips,kind='count')

# %%
sns.catplot("day",data=tips,kind='count',hue='smoker')

# %%
sns.catplot("day",data=tips,kind='count',hue='smoker',hue_order=['No','Yes'])

# %%
sns.boxplot(tips['tip'])

# %%
sns.boxplot(y=tips['tip'])

# %%
sns.boxplot(y='tip',data=tips)

# %%
sns.countplot(tips['day'])

# %%
sns.catplot("day",data=tips,kind='count',hue='smoker')

# %% [markdown]
# ### Distribution

# %%
sns.distplot(tips['tip'])

# %%
sns.distplot(tips['tip'],kde=False)

# %%
sns.distplot(tips['tip'],hist=False)

# %%
sns.distplot(tips['tip'],kde=False,rug=True)

# %%
sns.distplot(tips['tip'],rug=True)

# %%
sns.jointplot('total_bill','tip',data=tips)

# %%
sns.jointplot('total_bill','tip',data=tips,kind='kde')

# %% [markdown]
# ### paiwise plot for the numerical columns
#
#  - relplot
#  - scatterplot`

# %% [markdown]
# #### Getting numerical columns

# %%
tips.dtypes!='category'
# Out:
# total_bill     True
# tip            True
# sex           False
# smoker        False
# day           False
# time          False
# size           True
# dtype: bool

# %%
num_col = tips.columns[tips.dtypes!='category']

# %%
val = 1
for i in range(len(num_col)):
    for j in range(len(num_col)):
        plt.subplot(3,3,val)
        plt.scatter(tips[num_col[i]],tips[num_col[j]])
        plt.title(num_col[i]+'_'+num_col[j])
        val += 1

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips,hue='smoker')

# %%
sns.pairplot(tips,hue='sex')

# %%
sns.pairplot(tips,hue='sex',kind='reg')

# %% [markdown]
# ### style

# %%
sns.set(style='whitegrid')
sns.regplot("tip","total_bill",data=tips)

# %% [markdown]
# ## heatmap

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr())
