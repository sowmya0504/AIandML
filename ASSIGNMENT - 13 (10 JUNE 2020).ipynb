# %% [markdown]
# ### Assignment 13 ( 10 june 2020)

# %% [markdown]
# ### CSE-221710310031-B10

# %%
##1.Import the required packages
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
2##.Print version of each packages you have imported
print(sns.__version__)
print(pd.__version__)
print(np.__version__)
# Out:
# 0.10.0
# 1.0.1
# 1.18.1

# %%
##3.read the data using pandas
##store it in variable df
df=pd.read_csv("https://raw.githubusercontent.com/sumathi16/Datasets/master/upvotes.csv")
df
# Out:
#             ID Tag  Reputation  Answers  Username    Views  Upvotes
# 0        52664   a      3942.0      2.0    155623   7855.0     42.0
# 1       327662   a     26046.0     12.0     21781  55801.0   1175.0
# 2       468453   c      1358.0      4.0     56177   8067.0     60.0
# 3        96996   a       264.0      3.0    168793  27064.0      9.0
# 4       131465   c      4271.0      4.0    112223  13986.0     83.0
# ...        ...  ..         ...      ...       ...      ...      ...
# 330040  339800   c        36.0      2.0     84919   1063.0      0.0
# 330041  253800   c      1649.0      2.0     76730  23319.0     73.0
# 330042  210756   c      6178.0      2.0     91701   2453.0     15.0
# 330043   56089   j        89.0      2.0     80245   2107.0      3.0
# 330044  300553   j      2001.0      4.0    154692   2554.0     37.0
#
# [330045 rows x 7 columns]

# %%
##4.Understanding the data
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330045 entries, 0 to 330044
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   ID          330045 non-null  int64
#  1   Tag         330045 non-null  object
#  2   Reputation  330045 non-null  float64
#  3   Answers     330045 non-null  float64
#  4   Username    330045 non-null  int64
#  5   Views       330045 non-null  float64
#  6   Upvotes     330045 non-null  float64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 17.6+ MB
# (330045, 7)

# %%
#Print the numerical column names

import pandas as pd
import numpy as np
df = pd.read_csv("https://raw.githubusercontent.com/sumathi16/Datasets/master/upvotes.csv")
cols = df.select_dtypes([np.number]).columns
print (cols)
# Out:
# Index(['ID', 'Reputation', 'Answers', 'Username', 'Views', 'Upvotes'], dtype='object')

# %%
#How many rows are there in the data?

index = df.index
no_of_rows = len(index)
print("total no of rows :",no_of_rows)
# Out:
# total no of rows : 330045

# %%
#How many columns are there?

print("no of columns :",len(df.columns))
# Out:
# no of columns : 7

# %%
#How many categorical columns are there?

import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/sumathi16/Datasets/master/upvotes.csv", header=None)
df.select_dtypes(exclude=['int', 'float']).columns
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (0,2,3,4,5,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Int64Index([0, 1, 2, 3, 4, 5, 6], dtype='int64')

# %%
##5.Observe statistical description of the numerical columns
df.describe()
# Out:
#              0       1         2         3       4         5         6
# count   330046  330046  330046.0  330046.0  330046  330046.0  330046.0
# unique  330046      11   28959.0     118.0  177078  113920.0   10258.0
# top     395160       c       0.0       2.0    4118      70.0       3.0
# freq         1   72458    3950.0   43116.0     479      61.0    6967.0

# %%
upvotes = sns.load_dataset("upvotes")
upvotes
# Out:
#             ID Tag  Reputation  Answers  Username    Views  Upvotes
# 0        52664   a      3942.0      2.0    155623   7855.0     42.0
# 1       327662   a     26046.0     12.0     21781  55801.0   1175.0
# 2       468453   c      1358.0      4.0     56177   8067.0     60.0
# 3        96996   a       264.0      3.0    168793  27064.0      9.0
# 4       131465   c      4271.0      4.0    112223  13986.0     83.0
# ...        ...  ..         ...      ...       ...      ...      ...
# 330040  339800   c        36.0      2.0     84919   1063.0      0.0
# 330041  253800   c      1649.0      2.0     76730  23319.0     73.0
# 330042  210756   c      6178.0      2.0     91701   2453.0     15.0
# 330043   56089   j        89.0      2.0     80245   2107.0      3.0
# 330044  300553   j      2001.0      4.0    154692   2554.0     37.0
#
# [330045 rows x 7 columns]

# %%
#6a. draw the plot using data argument
sns.relplot("Upvotes","Views",data=upvotes)

# %%
#6b. check it with one categorical column as hue
plt.scatter(x = 'Upvotes', y = 'Views')

# %%
#7a . check it with one numerical column as hue
sns.relplot("Upvotes","Views",data=upvotes,hue="Answers")

# %%
#7b. check it with one categorical column as hue
sns.relplot("Upvotes","Views",data=upvotes,hue="Tag")

# %%
#9. Modify the above plot using any of the parameters size,style,col
sns.relplot("Upvotes","Views",data=upvotes,hue="Answers",size="Answers")

# %%
#10.Draw the cat plot by taking tag on xaxis and upvotes on yaxis
sns.catplot("Tag","Upvotes",data=upvotes)

# %%
#11. Draw the suitable plot to display How many questions are there for each Tag
sns.relplot("Tag","Answers",data=upvotes)

# %%
#12. Draw the suitable plot which will provide estimated line fit for the Answers and Upvotes
sns.relplot("Upvotes","Answers",data=upvotes,kind='line')

# %%
#13. Draw the boxplot for all the numerical columns
sns.catplot("Answers","Views",data=upvotes,kind='box')

# %%
sns.catplot("ID","Answers",data=upvotes,kind='box')

# %%
Draw the boxplot for all the numerical columns
sns.catplot("ID","Reputation",data=upvotes,kind='box')

# %%
Draw the boxplot for all the numerical columns
sns.catplot("Upvotes","Reputation",data=upvotes,kind='box')

# %%
Draw the boxplot for all the numerical columns
sns.catplot("Reputation","Answers",data=upvotes,kind='box')

# %%
Draw the boxplot for all the numerical columns
sns.catplot("Upvotes","Answers",data=upvotes,kind='box')

# %%
#15. Draw the pairplot
sns.pairplot(upvotes)

# %%
#16. Caluculate the correlation among all the possible numerical columns. Represnt those values using a suitable graph¶
upvotes.dtypes!='category'
# Out:
# ID            True
# Tag           True
# Reputation    True
# Answers       True
# Username      True
# Views         True
# Upvotes       True
# dtype: bool

# %%
num_col = upvotes.columns[upvotes.dtypes!='category']

# %%
val = 1
for i in range(len(num_col)):
    for j in range(len(num_col)):
        
        plt.scatter(upvotes[num_col[i]],upvotes[num_col[j]])
        plt.title(num_col[i]+'_'+num_col[j])
        val += 1

# %%
##17
#Get the data with tag 'a' in a new dataframe with name df_taga
df.Tag='a'

# %% [markdown]
# df_tag= df.Tag

# %%
#18.With the dataframe(df_taga) try any three plots We discussed either in matplotlib or seaborn
plt.plot(df_tag)

# %%
plt.bar(df_tag,height=0.5)
# Out:
# <BarContainer object of 1 artists>

# %%
#20. Draw a boxplot by taking Ans column on Xaxis and Upvotes on Y axis
#a. try this with boxplot
sns.boxplot(y='Upvotes',x='Answers',data=upvotes)

# %%
#20b. try this with catplot
sns.catplot(y='Upvotes',x='Answers',data=upvotes,kind='box')
